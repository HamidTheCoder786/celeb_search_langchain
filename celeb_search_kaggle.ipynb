# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # to be done parallely :
#     * oops in python
#     * fetching api in python
#     * hugging face spaces

# %%
print("meow")
# Out:
# meow
